# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import interp1d

# %%
data = np.loadtxt('DOSCAR', dtype=float, skiprows=6)
energy = data[:, 0]
DOS_up = data[:, 1]
data
# Out:
# array([[-7.000e+00,  7.906e-01,  7.905e-01,  6.720e-03,  6.720e-03],
#        [-6.992e+00,  6.731e-03,  6.731e-03,  6.777e-03,  6.777e-03],
#        [-6.983e+00,  6.637e-03,  6.638e-03,  6.833e-03,  6.833e-03],
#        ...,
#        [ 9.983e+00,  0.000e+00,  0.000e+00,  8.333e-02,  8.333e-02],
#        [ 9.992e+00,  0.000e+00,  0.000e+00,  8.333e-02,  8.333e-02],
#        [ 1.000e+01,  0.000e+00,  0.000e+00,  8.333e-02,  8.333e-02]])

# %%
ref = np.loadtxt('dos_Ge.dat')
plt.plot(ref[:,0], ref[:,1])

# %%
# %matplotlib notebook
x_new = np.linspace(-7, 10, 1000)

plt.plot(energy, data[:, 1])
plt.plot(ref[:,0]-2.6, ref[:,1]/120)
plt.xlim(-7, 10)
plt.ylim(0, 0.02)
plt.axvline(x=3.32)
plt.axvline(x=3.32+0.74)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ![title](ge_dos.png)

# %%
http://lampx.tugraz.at/~hadley/ss1/bands/bandstructures/Ge/ge_dos.html
# Out:
#   File "<ipython-input-94-512dd65bd875>", line 1
#     http://lampx.tugraz.at/~hadley/ss1/bands/bandstructures/Ge/ge_dos.html
#          ^
# SyntaxError: invalid syntax
