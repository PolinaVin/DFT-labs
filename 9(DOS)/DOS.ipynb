# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import interp1d

# %%
data = np.loadtxt('DOSCAR', dtype=float, skiprows=6)
energy = data[:, 0]
DOS_up = data[:, 1]
data[:, 0]
# Out:
# array([-7.   , -6.992, -6.983, ...,  9.983,  9.992, 10.   ])

# %%
# %matplotlib notebook
ref = np.loadtxt('dos_Ge.dat')
x0 = -1.65
i = np.argmin(np.abs(ref[:, 0]-x0))
plt.plot(ref[:,0], ref[:,1])
plt.axvline(x=-1.65)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
i = np.argmin(DOS_up)
j = np.argmin(ref[:,1])
i-j
# Out:
# 1816

# %%
# %matplotlib notebook
x1 = -4
plt.plot(energy, data[:, 1])
plt.plot(ref[:,0]+x1-x0, ref[:,1]/100, label='ref')
plt.xlim(-7, 10)
plt.ylim(0, 0.03)
#plt.axvline(x=3.32)
#plt.axvline(x=3.32+0.74)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 0.03)

# %% [markdown]
# ![title](ge_dos.png)

# %%
http://lampx.tugraz.at/~hadley/ss1/bands/bandstructures/Ge/ge_dos.html
# Out:
#   File "<ipython-input-94-512dd65bd875>", line 1
#     http://lampx.tugraz.at/~hadley/ss1/bands/bandstructures/Ge/ge_dos.html
#          ^
# SyntaxError: invalid syntax
