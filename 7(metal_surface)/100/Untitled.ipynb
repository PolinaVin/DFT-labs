# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = [1.41042,  2.839732, 4.202285,  5.636574,  7.012769]
d = np.array(d)-np.array([0, 1.41042,  2.839732, 4.202285,  5.636574])
d = (d-1.41042)/1.41042*100
d
# Out:
# array([ 0.        ,  1.33945917, -3.39381177,  1.69233278, -2.42658215])

# %%
# %matplotlib notebook
plt.plot(np.arange(5), d[::-1], '.-')
plt.xticks(ticks= np.arange(5), labels= [r'$d_{12}$', r'$d_{23}$', r'$d_{34}$', r'$d_{45}$', r'$d_{56}$'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x19fdb92ff40>,
# ...
#  [Text(0, 0, '$d_{12}$'),
#   Text(1, 0, '$d_{23}$'),
#   Text(2, 0, '$d_{34}$'),
#   Text(3, 0, '$d_{45}$'),
#   Text(4, 0, '$d_{56}$')])

# %%
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-42-37c8be27b957> in <module>
# ----> 1 np.add(np.arange(5), '1')
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U11'), dtype('<U11')) -> dtype('<U11')

# %%
d = 1.41042
d*np.arange(6)
# Out:
# array([0.     , 1.41042, 2.82084, 4.23126, 5.64168, 7.0521 ])
